# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import os
print(os.listdir("C:\\unzipped\\120-years-of-olympic-history-athletes-and-results\\"))
# Out:
# ['athlete_events.csv', 'noc_regions.csv']

# %%
data = pd.read_csv('C:\\unzipped\\120-years-of-olympic-history-athletes-and-results\\athlete_events.csv')
regions = pd.read_csv('C:\\unzipped\\120-years-of-olympic-history-athletes-and-results\\noc_regions.csv')

# %%
data.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
regions.head(5)
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
merged = pd.merge(data, regions, on='NOC', how='left')

# %%
merged.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
goldMedals = merged[(merged['Medal'] == 'Gold')]

# %%
goldMedals.head(5)
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   region notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %%
plt.figure(figsize=(20, 10))
#plt.tight_layout()
sns.countplot(goldMedals['Age'])
plt.title('Distribution of Gold Medals')
# Out:
# Text(0.5,1,'Distribution of Gold Medals')

# %%
goldMedals['ID'][goldMedals.Age > 50].count()
# Out:
# 65

# %%
masterDisciplines = goldMedals['Sport'][goldMedals['Age'] > 50]

# %%
masterDisciplines.head(5)
# Out:
# 5078     Equestrianism
# 7961           Sailing
# 13394    Equestrianism
# 13396    Equestrianism
# 24897    Equestrianism
# Name: Sport, dtype: object

# %%
plt.figure(figsize=(20,10))
plt.tight_layout()
sns.countplot(masterDisciplines)
plt.title('Gold Medals for Athletes over 50')
# Out:
# Text(0.5,1,'Gold Medals for Athletes over 50')

# %%
womenAth = merged[(merged['Sex']=='F')]

# %%
womenAth.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal       region notes
# 4    Speed Skating Women's 500 metres   NaN  Netherlands   NaN
# ...

# %%
womenAth.plot.hist()

# %%
#sns.set(style='darkgrid')
plt.figure(figsize=(15,10))
plt.tight_layout()
sns.countplot(x='Year' , data=womenAth)
plt.title('Women medals per edition of game')
# Out:
# Text(0.5,1,'Women medals per edition of game')

# %%
womenAth['ID'].loc[womenAth['Year'] == 1900].count()
# Out:
# 33

# %% [markdown]
# womenAth.loc[womenAth['region']=='India'].head(10)

# %%
womenInd=womenAth.loc[womenAth['region']=='India']
womenInd.head(5)
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 898  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 899  512  Shiny Kurisingal Abraham-Wilson   F  27.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
# 898  IND  1988 Summer  1988  Summer        Seoul  Athletics
# 899  IND  1992 Summer  1992  Summer    Barcelona  Athletics
#
#                                       Event Medal region notes
# 895            Athletics Women's 800 metres   NaN  India   NaN
# ...

# %%
plt.figure(figsize=(10,10))
plt.tight_layout()
sns.countplot(womenInd.Age)
plt.title('Gold Medals won by Indian women')
# Out:
# Text(0.5,1,'Gold Medals won by Indian women')

# %%
totalMedals=goldMedals.region.value_counts().reset_index(name ='Medals').head(5)
totalMedals
# Out:
#      index  Medals
# 0      USA    2638
# 1   Russia    1599
# 2  Germany    1301
# 3       UK     678
# 4    Italy     575

# %%
g = sns.countplot(x="index", data=totalMedals)
#g.despine(left=True)
g.set_xlabels("Top 5 countries")
g.set_ylabels("Number of Medals")
plt.title('Medals per Country')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-24-8efa19b83b69> in <module>()
#       1 g = sns.countplot(x="index", data=totalMedals)
#       2 #g.despine(left=True)
# ----> 3 g.set_xlabels("Top 5 countries")
#       4 g.set_ylabels("Number of Medals")
#       5 plt.title('Medals per Country')
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xlabels'

# %%
goldMedalsInd = goldMedals.loc[goldMedals['region']=='India']

# %%
goldMedalsInd.head()
# Out:
#         ID                 Name Sex   Age  Height  Weight   Team  NOC  \
# 4732  2699          Shaukat Ali   M  30.0     NaN     NaN  India  IND
# 4736  2703     Syed Mushtaq Ali   M  22.0   165.0    61.0  India  IND
# 5032  2864  Richard James Allen   M  25.0   172.0     NaN  India  IND
# 5033  2864  Richard James Allen   M  30.0   172.0     NaN  India  IND
# 5034  2864  Richard James Allen   M  34.0   172.0     NaN  India  IND
#
#             Games  Year  Season         City   Sport                Event  \
# 4732  1928 Summer  1928  Summer    Amsterdam  Hockey  Hockey Men's Hockey
# 4736  1964 Summer  1964  Summer        Tokyo  Hockey  Hockey Men's Hockey
# 5032  1928 Summer  1928  Summer    Amsterdam  Hockey  Hockey Men's Hockey
# 5033  1932 Summer  1932  Summer  Los Angeles  Hockey  Hockey Men's Hockey
# 5034  1936 Summer  1936  Summer       Berlin  Hockey  Hockey Men's Hockey
#
#      Medal region notes
# 4732  Gold  India   NaN
# 4736  Gold  India   NaN
# ...

# %%
goldMedalsInd.ID.count()
# Out:
# 138

# %%
goldMedalsInd.Event.value_counts().reset_index(name='Medals')
# Out:
#                                  index  Medals
# 0                  Hockey Men's Hockey     130
# 1              Alpinism Mixed Alpinism       7
# 2  Shooting Men's Air Rifle, 10 metres       1

# %%
goldMedalsInd
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 4732      2699                      Shaukat Ali   M  30.0     NaN     NaN
# 4736      2703                 Syed Mushtaq Ali   M  22.0   165.0    61.0
# 5032      2864              Richard James Allen   M  25.0   172.0     NaN
# 5033      2864              Richard James Allen   M  30.0   172.0     NaN
# 5034      2864              Richard James Allen   M  34.0   172.0     NaN
# 10274     5618            Sardar Mohammad Aslam   M   NaN     NaN     NaN
# 21208    11197              Vasudevan Bhaskaran   M  29.0   174.0    68.0
# 22004    11601                   Abhinav Bindra   M  25.0   173.0    70.0
# 24657    12911              Lal Shah S. Bokhari   M  23.0   173.0     NaN
# 29022    15011  Frank Gerald Singlehurst Brewin   M  22.0     NaN     NaN
# 35960    18475       Richard John "Dickie" Carr   M  21.0   180.0     NaN
# 38352    19716                 Dhyan Chand Bais   M  22.0   169.0     NaN
# ...

# %%
plt.figure(figsize=(10,5))
plt.tight_layout()
sns.countplot(goldMedalsInd.Event)

# %%
plt.figure(figsize=(20,20))
plt.tight_layout()
sns.countplot(goldMedalsInd.Year)
plt.savefig('C:\Users\Rahil Desai\Desktop\yearwisegoldIndia.jpg')

# %%
plt.figure(figsize=(20,10))
plt.tight_layout()
sns.scatterplot(x='Sport',y='Year',data=goldMedalsInd)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-35-570076a94ef6> in <module>()
#       1 plt.figure(figsize=(20,10))
#       2 plt.tight_layout()
# ----> 3 sns.scatterplot(x='Sport',y='Year',data=goldMedalsInd)
#
# AttributeError: 'module' object has no attribute 'scatterplot'

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>
